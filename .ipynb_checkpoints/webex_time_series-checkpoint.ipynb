# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from pandas_ods_reader import read_ods

from dateutil.parser import parse

# %%
april = pd.read_csv('SiroveKopijeWebexMeetings/April2021_Webex Meetings_Attendees_matf.webex.com_2021-04-01_2021-04-30.csv', parse_dates=['JOIN_DATE'])
may = pd.read_csv('SiroveKopijeWebexMeetings/Maj2021_Webex Meetings_Attendees_matf.webex.com_2021-05-01_2021-05-31.csv', parse_dates=['JOIN_DATE'])

# %%
march = read_ods('SiroveKopijeWebexMeetings/Mart2021WebexMeetingsAttendees.ods', 1)
november = read_ods('SiroveKopijeWebexMeetings/NovembarWebex Meetings_Attendees_matf.webex.com_2020-11-01_2020-11-30.ods', 1)

# %%
april.head()
# Out:
#    MEETING_NUMBER                                       MEETING_NAME  \
# 0      1834853439  МАТФ - Увод у веб и интернет технологије (вежб...
# 1      1830843747                  Analiza 3, I smer, 2. tok - vezbe
# 2      1833007854                                     EFM predavanja
# 3      1837521894                       Практикум из Анализе 1 - П12
# 4      1831753884                                          г4, вежбе
#
#         CONFERENCE_ID          USER_NAME                       EMAIL LOCATION  \
# 0  189215711830219865         Lena Polic  mi17219@alas.matf.bg.ac.rs   Serbia
# 1  189755459960315839     Luka Radanovic  mi19169@alas.matf.bg.ac.rs   Serbia
# 2  189774169196469618  Ilija-Petar Milić           ipmilic@gmail.com   Serbia
# 3  189846157149609508    Jana Mihajlović  janamihajlovic04@gmail.com   Serbia
# 4  190106877640580240  Dragana Maljković  mv17007@alas.matf.bg.ac.rs   Serbia
#
#    JOIN_DATE           START_TIME             END_TIME  DURATION  ...  \
# 0 2021-04-02  2021-04-02T10:13:34  2021-04-02T11:59:55       107  ...
# 1 2021-04-01  2021-04-01T09:06:19  2021-04-01T11:02:40       117  ...
# 2 2021-04-01  2021-04-01T13:05:16  2021-04-01T13:18:56        14  ...
# 3 2021-04-02  2021-04-02T10:15:33  2021-04-02T10:58:13        43  ...
# 4 2021-04-05  2021-04-05T07:24:58  2021-04-05T09:07:37       103  ...
#
#        GATEWAY_IP JOIN_MEETING_TIME VOIP_PACKET_LOSS VOIP_LATENCY  \
# 0   87.116.165.39             0.413          0.00065    50.000000
# 1  89.110.244.200             0.849          0.00000    50.000000
# 2  87.116.165.160             0.920          0.00000    50.000000
# 3   109.92.158.89             2.188          0.00000   100.064482
# 4   178.221.45.78            40.543          0.00000   101.919657
#
#    TCP_PERCENTAGE  UDP_PERCENTAGE  IS_CMR  IS_SHARING  IS_RECORD VIDEO_MINUTES
# 0             0.0             1.0       N           N          N           NaN
# 1             0.0             1.0       N           N          N           NaN
# 2             0.0             1.0       N           N          N           NaN
# 3             0.0             1.0       N           N          N           NaN
# 4             0.0             1.0       N           N          N           NaN
#
# [5 rows x 23 columns]

# %%
april.shape
# Out:
# (22549, 23)

# %%
april.columns
# Out:
# Index(['MEETING_NUMBER', 'MEETING_NAME', 'CONFERENCE_ID', 'USER_NAME', 'EMAIL',
#        'LOCATION', 'JOIN_DATE', 'START_TIME', 'END_TIME', 'DURATION', 'OS',
#        'BROWSER', 'CLIENT_IP', 'GATEWAY_IP', 'JOIN_MEETING_TIME',
#        'VOIP_PACKET_LOSS', 'VOIP_LATENCY', 'TCP_PERCENTAGE', 'UDP_PERCENTAGE',
#        'IS_CMR', 'IS_SHARING', 'IS_RECORD', 'VIDEO_MINUTES'],
#       dtype='object')

# %%
april.isnull().any()
# Out:
# MEETING_NUMBER       False
# MEETING_NAME         False
# CONFERENCE_ID        False
# USER_NAME            False
# EMAIL                 True
# LOCATION             False
# JOIN_DATE            False
# START_TIME           False
# END_TIME             False
# DURATION             False
# OS                   False
# BROWSER              False
# CLIENT_IP            False
# GATEWAY_IP           False
# JOIN_MEETING_TIME     True
# VOIP_PACKET_LOSS      True
# VOIP_LATENCY          True
# TCP_PERCENTAGE        True
# UDP_PERCENTAGE        True
# IS_CMR               False
# IS_SHARING           False
# IS_RECORD            False
# VIDEO_MINUTES         True
# dtype: bool

# %%
april.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22549 entries, 0 to 22548
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MEETING_NUMBER     22549 non-null  int64
#  1   MEETING_NAME       22549 non-null  object
#  2   CONFERENCE_ID      22549 non-null  int64
#  3   USER_NAME          22549 non-null  object
#  4   EMAIL              22543 non-null  object
#  5   LOCATION           22549 non-null  object
#  6   JOIN_DATE          22549 non-null  datetime64[ns]
#  7   START_TIME         22549 non-null  object
#  8   END_TIME           22549 non-null  object
#  9   DURATION           22549 non-null  int64
#  10  OS                 22549 non-null  object
#  11  BROWSER            22549 non-null  object
#  12  CLIENT_IP          22549 non-null  object
#  13  GATEWAY_IP         22549 non-null  object
#  14  JOIN_MEETING_TIME  22544 non-null  float64
#  15  VOIP_PACKET_LOSS   18264 non-null  float64
#  16  VOIP_LATENCY       18264 non-null  float64
#  17  TCP_PERCENTAGE     18259 non-null  float64
#  18  UDP_PERCENTAGE     18259 non-null  float64
#  19  IS_CMR             22549 non-null  object
#  20  IS_SHARING         22549 non-null  object
#  21  IS_RECORD          22549 non-null  object
#  22  VIDEO_MINUTES      1621 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(13)
# memory usage: 4.0+ MB

# %%
meetings_per_day_april = april.groupby(['JOIN_DATE']).MEETING_NUMBER.count()
meetings_per_day_march = march.groupby(['JOIN_DATE']).MEETING_NUMBER.count()
meetings_per_day_november = november.groupby(['JOIN_DATE']).MEETING_NUMBER.count()
meetings_per_day_may = may.groupby(['JOIN_DATE']).MEETING_NUMBER.count()

# %%
def plot_df(df, x, y, title="", xlabel='Datum', ylabel='Vrednost', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

# %%
plot_df(meetings_per_day_march, meetings_per_day_march.index, meetings_per_day_march.values, title="Broj sastanaka po danu (MART)")

# %%
plot_df(meetings_per_day_april, meetings_per_day_april.index, meetings_per_day_april.values, title="Broj sastanaka po danu (APRIL)")

# %%
plot_df(meetings_per_day_may, meetings_per_day_may.index, meetings_per_day_may.values, title="Broj sastanaka po danu (MAJ)")

# %%
fig, axs = plt.subplots(2, 2, figsize=(15,10))
axs[0, 0].plot(meetings_per_day_march.index, meetings_per_day_march.values)
axs[0, 0].set_title('Mart')
axs[0, 1].plot(meetings_per_day_april.index, meetings_per_day_april.values, 'tab:orange')
axs[0, 1].set_title('April')
axs[1, 0].plot(meetings_per_day_may.index, meetings_per_day_may.values, 'tab:green')
axs[1, 0].set_title('Maj')
axs[1, 1].plot(meetings_per_day_november.index, meetings_per_day_november.values, 'tab:red')
axs[1, 1].set_title('Novembar')

for ax in axs.flat:
    ax.set(xlabel='Datum', ylabel='Vrednost')

for ax in axs.flat:
    ax.label_outer()

# %%
plot_df(meetings_per_day_november, meetings_per_day_november.index, meetings_per_day_november.values, title="Broj sastanaka po danu (NOVEMBAR)")

# %% [markdown]
# Prosecna duzina trajanja sastanaka svaki dan

# %%
duration_april = april.groupby(['JOIN_DATE']).DURATION.mean()
plot_df(duration_april, duration_april.index, duration_april.values, title='trajanje april')

# %%
df['Year'] = april.index.year
df['Month'] = april.index.month
df['Weekday Name'] = april.index.day_name()

april.sample(5, random_state=2)
